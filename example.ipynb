# %%
from main_VM import get_p_value_user, get_p_value_user_no_plot
import pandas as pd
import numpy as np
from collections import defaultdict
from datetime import datetime

# %%
trx_train = pd.read_csv('test_data/test_assessment.csv', header=0)
trx_train.DATE_TIMESTAMP_FIX = pd.to_datetime(trx_train.DATE_TIMESTAMP_FIX)

account = np.random.choice(trx_train.D_RPPUSERID_REAL.unique())

print(f'RPP_USER_ID: {account}')
n = 256

trx_ = trx_train[trx_train['D_RPPUSERID_REAL'] == account]
print(len(trx_))

timestamps = trx_.DATE_TIMESTAMP_FIX.values

time_segments = ['hour', 'daymonth', 'dayweek']
# Out:
# RPP_USER_ID: ae181e13-6bfc-40a0-8f57-a30119997920
# 210

# %%
get_p_value_user(n, timestamps, time_segments, plot=True)
# Out:
# 45.97103940029412 hour
# 499.9999865216339 daymonth
# 185.49052479006713 dayweek
# Results periodic time analyzers
# Number trx = 210
# Risk pvalue hour = 0.9999999997737704
# Risk pvalue daymonth = 0.9999999999798903
# Risk pvalue dayweek = 0.9999999997485791
# defaultdict(list,
#             {'hour': [256, 210, 45.97103940029412, 0.9999999997737704],
#              'daymonth': [256, 210, 499.9999865216339, 0.9999999999798903],
#              'dayweek': [256, 210, 185.49052479006713, 0.9999999997485791]})

# %%
get_p_value_user_no_plot(n, timestamps, time_segments)
# Out:
# defaultdict(list,
#             {'hour': [256,
#               210,
#               45.97103940029412,
#               0.9999999997737704,
#               0.8597719669342041],
#              'daymonth': [256,
#               210,
#               499.9999865216339,
#               0.9999999999798903,
#               2.1303579807281494],
#              'dayweek': [256,
#               210,
#               185.49052479006713,
#               0.9999999997485791,
#               0.6637787818908691]})
